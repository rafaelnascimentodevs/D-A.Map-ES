# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaelnascimentodevs/D-A.Map-ES/blob/main/mapES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geopandas matplotlib

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import os

# %%
os.environ['SHAPE_RESTORE_SHX'] = 'YES'

# %%
data = gpd.read_file('/content/ES_Municipios_2022.shp')

# %%
data.head(5)
# Out:
#                                             geometry
# 0  POLYGON ((-41.02167 -20.14893, -41.02002 -20.1...
# 1  POLYGON ((-40.74017 -19.02404, -40.74038 -19.0...
# 2  POLYGON ((-41.04399 -18.62669, -41.04398 -18.6...
# 3  POLYGON ((-41.48776 -20.60596, -41.48743 -20.6...
# 4  POLYGON ((-40.78714 -20.50978, -40.78676 -20.5...

# %%
data.plot()
# Out:
# <Axes: >

# %%
data
# Out:
#                                              geometry
# 0   POLYGON ((-41.02167 -20.14893, -41.02002 -20.1...
# 1   POLYGON ((-40.74017 -19.02404, -40.74038 -19.0...
# 2   POLYGON ((-41.04399 -18.62669, -41.04398 -18.6...
# 3   POLYGON ((-41.48776 -20.60596, -41.48743 -20.6...
# 4   POLYGON ((-40.78714 -20.50978, -40.78676 -20.5...
# ..                                                ...
# 73  POLYGON ((-40.40489 -20.36815, -40.40491 -20.3...
# 74  POLYGON ((-40.53558 -18.60442, -40.53543 -18.6...
# 75  POLYGON ((-40.24231 -18.98558, -40.26389 -19.0...
# 76  MULTIPOLYGON (((-40.32212 -20.32513, -40.32185...
# 77  MULTIPOLYGON (((-40.29020 -20.28757, -40.29024...
#
# [78 rows x 1 columns]

# %%
data.plot(figsize = (16, 14 ), facecolor = 'white' , edgecolor = 'black' )
# Out:
# <Axes: >
